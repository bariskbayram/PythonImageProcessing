# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
def createCircularMask(h, w, center=None, radius=None):
    if center is None:  # use the middle of the image
        center = [int(w/2), int(h/2)]
    if radius is None:  # use the smallest distance between the center and image walls
        radius = min(center[0], center[1], w-center[0], h-center[1])
    y, x = np.ogrid[:h, :w]
    dist_from_center = np.sqrt((x - center[0])**2 + (y-center[1])**2)

    mask = dist_from_center <= radius
    return mask

# %%
img = plt.imread("images.jpeg")
plt.imshow(img, cmap="gray")
plt.show()
h, w = img.shape[:2]
radius = h/4
mask = createCircularMask(h, w, radius=radius)
image = np.zeros((h,w,3), dtype=int)
image[:,:,:] = img[:,:,:]
image[~mask] = 0
plt.imshow(image)
plt.show()

# %%
img=mpimg.imread('images.jpeg')
plt.imshow(img)
plt.show()

# %%
img_1=img[1:375:2,:,:]
img_1=img_1[:,1:500:2,:]

plt.subplot(1,2,1),plt.imshow(img)
plt.subplot(1,2,2),plt.imshow(img_1)
plt.show()

# %%
m,n,p = img.shape
img_30=np.zeros((500,375,3), dtype=int)
for i in range(375):
    for j in range(500):
        img_30[j,i,:]=1-img[i,j,:]
plt.imshow(img_30)
plt.show()

# %%
img_40=np.zeros((375,500,3), dtype=int)
for i in range(375):
    for j in range(500):
        img_40[375-i-1,500-j-1,:]=1-img[i,j,:]   
plt.imshow(img_40)
plt.show()

# %%
img_50=np.zeros((375,500,3), dtype=int)
for i in range(375):
    for j in range(500):
        img_50[375-i-1,j,:]=1-img[i,j,:]
plt.imshow(img_50)
plt.show()
